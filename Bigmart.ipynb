# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
plt.rcParams['figure.figsize'] = 15,12

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df=pd.read_csv(r'C:\Users\suhasmamidi\Suhas Python\bigmart.csv')

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
df.sample(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8254           FDD04       16.000          Low Fat         0.089896
# 7888           FDW49       19.500          Low Fat         0.083019
# 4616           FDX32       15.100          Regular         0.100265
# 7079           FDW51        6.155          Regular         0.095045
# 7080           FDR28       13.850          Regular         0.025892
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 8254                  Dairy  143.4154            OUT013
# 7888                 Canned  180.2002            OUT017
# 4616  Fruits and Vegetables  142.5786            OUT018
# 7079                   Meat  213.4560            OUT018
# 7080           Frozen Foods  165.1210            OUT035
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8254                       1987        High               Tier 3
# 7888                       2007         NaN               Tier 2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.1+ KB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df[df['Item_Identifier'] == "FDP10"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 585            FDP10         19.0          Low Fat         0.128066
# 2623           FDP10         19.0          Low Fat         0.128815
# 3382           FDP10         19.0          Low Fat         0.128289
# 4585           FDP10         19.0          Low Fat         0.128090
# 6087           FDP10         19.0          Low Fat         0.128350
# 7883           FDP10         19.0          Low Fat         0.127984
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7     Snack Foods  107.7622            OUT027                       1985
# 585   Snack Foods  104.3622            OUT035                       2004
# 2623  Snack Foods  107.6622            OUT017                       2007
# 3382  Snack Foods  104.9622            OUT049                       1999
# ...

# %%
df['Item_Outlet_Sales'].describe()
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %%
sns.distplot(df['Item_Outlet_Sales'])

# %%
print("Skewness: %f" % df['Item_Outlet_Sales'].skew())
print("Kurtosis: %f" % df['Item_Outlet_Sales'].kurt())
# Out:
# Skewness: 1.177531
# Kurtosis: 1.615877

# %%
target = np.log(df['Item_Outlet_Sales'])

# %%
sns.distplot(target)

# %%
print("Skewness: %f" % target.skew())
print("Kurtosis: %f" % target.kurt())
# Out:
# Skewness: -0.887753
# Kurtosis: 0.552055

# %%
var = 'Outlet_Establishment_Year'
data = pd.concat([df['Item_Outlet_Sales'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="Item_Outlet_Sales", data=data)
fig.axis(ymin=0, ymax=15000);

# %%
#Convert the outlet establishment year into number of years passed
df['Year_Passed'] = 2019 -  df['Outlet_Establishment_Year']

# %%
df.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                         20      Medium               Tier 1
# 1                         10      Medium               Tier 3
# ...

# %%
plt.rcParams['figure.figsize'] = (20, 12)

plt.subplot(1, 1, 1)
sns.countplot(x="Item_Type", hue="Outlet_Establishment_Year", data=df)

# %%
#Sales vs Outlet type
plt.rcParams['figure.figsize'] = (20, 12)

plt.subplot(1, 1, 1)
sns.barplot(x="Outlet_Type", y="Item_Outlet_Sales", data=df)

# %%
#try box plot as well as violin plot
ax = sns.violinplot(x="Item_Type", y="Item_Outlet_Sales", data=df)
# sales of each item type.

# %%
plt.rcParams['figure.figsize'] = (20, 12)
#Items having more sales vs Outlet type vs outlet type

plt.subplot(1, 1, 1)
sns.barplot(x="Item_Type", y="Item_Outlet_Sales", hue="Outlet_Type", data=df)

# %%
var = 'Item_Type'
data = pd.concat([df['Item_Outlet_Sales'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(15,6))
fig = sns.boxplot(x=var, y="Item_Outlet_Sales", data=data)
fig.axis(ymin=0, ymax=15000);
#To identify sales of each individual product

# %%
plt.rcParams['figure.figsize'] = (20, 12)

plt.subplot(1, 1, 1)
sns.barplot(x="Outlet_Size", y="Item_Outlet_Sales", hue="Item_Type", data=df)

# %%
plt.rcParams['figure.figsize'] = (20, 12)
# to check whether the supermarket 3 is in medium  outlet size w.r.to sales.
plt.subplot(1, 1, 1)
sns.barplot(x="Outlet_Size", y="Item_Outlet_Sales", hue="Outlet_Type", data=df)

# %%
plt.rcParams['figure.figsize'] = (20, 12)

plt.subplot(1, 1, 1)
sns.barplot(x="Outlet_Type", y="Item_Outlet_Sales", hue="Item_Type", data=df)

# %%
df.head(25)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %%
df = df[(df['Item_Fat_Content'] == 'Regular') & (df['Item_Type'] == 'Soft Drinks')]

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 37             DRZ11        8.850          Regular         0.113124
# 103            DRB48       16.750          Regular         0.024833
# 165            DRL01       19.500          Regular         0.077609
# 178            DRY23          NaN          Regular         0.191014
# 458            DRB48          NaN          Regular         0.024733
# 576            DRB48       16.750          Regular         0.000000
# 1084           DRC36          NaN          Regular         0.044767
# 1148           DRA24       19.350          Regular         0.040154
# 1226           DRY23        9.395          Regular         0.109076
# 1253           DRC13        8.260          Regular         0.032435
# 1431           DRB13        6.115          Regular         0.007084
# 1667           DRL01       19.500          Regular         0.077108
# ...
